# %%
import pandas as pd
pd
# Out:
# <module 'pandas' from 'C:\\Users\\habildaniel\\anaconda3\\Lib\\site-packages\\pandas\\__init__.py'>

# %%
filepath = "DataFiles/data.xlsx"
df = pd.read_excel(filepath)

# %%
df
# Out:
#        name  age   department  salary
# 0     Alice   30           HR   50000
# 1       Bob   24  Engineering   60000
# 2   Charlie   26        Sales   55000
# 3     David   35  Engineering   80000
# 4       Eve   29           HR   52000
# 5     Frank   27        Sales   58000
# 6     Grace   31  Engineering   70000
# 7    Hannah   23        Sales   53000
# 8       Ian   34           HR   51000
# 9      Jack   28  Engineering   62000
# 10      Eve   29           HR   52000

# %%
df. head()
# Out:
#       name  age   department  salary
# 0    Alice   30           HR   50000
# 1      Bob   24  Engineering   60000
# 2  Charlie   26        Sales   55000
# 3    David   35  Engineering   80000
# 4      Eve   29           HR   52000

# %%
df. tail()
# Out:
#       name  age   department  salary
# 6    Grace   31  Engineering   70000
# 7   Hannah   23        Sales   53000
# 8      Ian   34           HR   51000
# 9     Jack   28  Engineering   62000
# 10     Eve   29           HR   52000

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        11 non-null     object
#  1   age         11 non-null     int64
#  2   department  11 non-null     object
#  3   salary      11 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 484.0+ bytes

# %%
df. shape
# Out:
# (11, 4)

# %%
df. columns
# Out:
# Index(['name', 'age', 'department', 'salary'], dtype='object')

# %%
df. describe()
# Out:
#              age        salary
# count  11.000000     11.000000
# mean   28.727273  58454.545455
# std     3.744086   9299.071312
# min    23.000000  50000.000000
# 25%    26.500000  52000.000000
# 50%    29.000000  55000.000000
# 75%    30.500000  61000.000000
# max    35.000000  80000.000000

# %%
selected = df[['age', 'salary']]

# %%
selected
# Out:
#     age  salary
# 0    30   50000
# 1    24   60000
# 2    26   55000
# 3    35   80000
# 4    29   52000
# 5    27   58000
# 6    31   70000
# 7    23   53000
# 8    34   51000
# 9    28   62000
# 10   29   52000

# %%
df. iloc[5:8]
# Out:
#      name  age   department  salary
# 5   Frank   27        Sales   58000
# 6   Grace   31  Engineering   70000
# 7  Hannah   23        Sales   53000

# %%
df.sort_values(by = "salary")
# Out:
#        name  age   department  salary
# 0     Alice   30           HR   50000
# 8       Ian   34           HR   51000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 7    Hannah   23        Sales   53000
# 2   Charlie   26        Sales   55000
# 5     Frank   27        Sales   58000
# 1       Bob   24  Engineering   60000
# 9      Jack   28  Engineering   62000
# 6     Grace   31  Engineering   70000
# 3     David   35  Engineering   80000

# %%
df.sort_values(by = "age", ascending=True)
# Out:
#        name  age   department  salary
# 7    Hannah   23        Sales   53000
# 1       Bob   24  Engineering   60000
# 2   Charlie   26        Sales   55000
# 5     Frank   27        Sales   58000
# 9      Jack   28  Engineering   62000
# 4       Eve   29           HR   52000
# 10      Eve   29           HR   52000
# 0     Alice   30           HR   50000
# 6     Grace   31  Engineering   70000
# 8       Ian   34           HR   51000
# 3     David   35  Engineering   80000

# %%
df[df["age"] < 25]
# Out:
#      name  age   department  salary
# 1     Bob   24  Engineering   60000
# 7  Hannah   23        Sales   53000

# %%
df[df["salary"] < 55000]
# Out:
#       name  age department  salary
# 0    Alice   30         HR   50000
# 4      Eve   29         HR   52000
# 7   Hannah   23      Sales   53000
# 8      Ian   34         HR   51000
# 10     Eve   29         HR   52000

# %%
df["Location"] = "Kitengela"
df
# Out:
#        name  age   department  salary   Location
# 0     Alice   30           HR   50000  Kitengela
# 1       Bob   24  Engineering   60000  Kitengela
# 2   Charlie   26        Sales   55000  Kitengela
# 3     David   35  Engineering   80000  Kitengela
# 4       Eve   29           HR   52000  Kitengela
# 5     Frank   27        Sales   58000  Kitengela
# 6     Grace   31  Engineering   70000  Kitengela
# 7    Hannah   23        Sales   53000  Kitengela
# 8       Ian   34           HR   51000  Kitengela
# 9      Jack   28  Engineering   62000  Kitengela
# 10      Eve   29           HR   52000  Kitengela

# %%
print(df.columns)
# Out:
# Index(['name', 'age', 'department', 'salary', 'Location'], dtype='object')

# %%
name_to_find = 'Hannah'      
new_location = 'Busia'
df.loc[df['name'] == name_to_find, 'Location'] = new_location
df
# Out:
#        name  age   department  salary   Location
# 0     Alice   30           HR   50000  Kitengela
# 1       Bob   24  Engineering   60000  Kitengela
# 2   Charlie   26        Sales   55000  Kitengela
# 3     David   35  Engineering   80000  Kitengela
# 4       Eve   29           HR   52000  Kitengela
# 5     Frank   27        Sales   58000  Kitengela
# 6     Grace   31  Engineering   70000  Kitengela
# 7    Hannah   23        Sales   53000      Busia
# 8       Ian   34           HR   51000  Kitengela
# 9      Jack   28  Engineering   62000  Kitengela
# 10      Eve   29           HR   52000  Kitengela

# %%
df. groupby(
# Out:
# <>:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# <>:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
# C:\Users\habildaniel\AppData\Local\Temp\ipykernel_6484\3300578070.py:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
#   df.groupby=("department")['salary'].sum()
# C:\Users\habildaniel\AppData\Local\Temp\ipykernel_6484\3300578070.py:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
#   df.groupby=("department")['salary'].sum()
# C:\Users\habildaniel\AppData\Local\Temp\ipykernel_6484\3300578070.py:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
#   df.groupby=("department")['salary'].sum()
# C:\Users\habildaniel\AppData\Local\Temp\ipykernel_6484\3300578070.py:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
#   df.groupby=("department")['salary'].sum()
# C:\Users\habildaniel\AppData\Local\Temp\ipykernel_6484\3300578070.py:1: SyntaxWarning: str indices must be integers or slices, not str; perhaps you missed a comma?
#   df.groupby=("department")['salary'].sum()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.groupby=("department")['salary'].sum()
#
# TypeError: string indices must be integers, not 'str'
